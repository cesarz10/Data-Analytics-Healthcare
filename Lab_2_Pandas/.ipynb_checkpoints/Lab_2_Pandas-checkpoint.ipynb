# %% [markdown]
# ### Submission guidelines

# %% [markdown]
# 1. Fill in your name in the notebook in the top cell.
# 2. Fill in the gaps in the code where indicated. <br> Make sure that you:<br> - fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE" <br> - **do not leave any `raise NotImplementedErrors`** in the code
# 3. Do **NOT change the variable names**, however, you can add comments in the code.
# 4. Do **NOT remove any of the cells** of the notebook!
# 5. Discussion is allowed, but every student needs to hand a personal version of the lab. Plagiarism will be sanctioned!
# 6. Before submitting, restart your kernel & **make sure that every cell runs**.<br>Code that doesn't run will not be scored.<br>The notebooks with all source code, and optional extra files need to be handed in using Ufora.<br> Make sure all your notebooks are already executed when you upload them (i.e. there should be output after the cells).
# 7. **Zip** your lab assignment folder and name the archive: `Surname_Name.zip` <br> Keep the same folder structure as the provided lab assignment!<br><span style='color: red'>Do not rename any of the notebooks or files</span>!<br>

# %%
NAME = "Cesar Zapata"

# %% [markdown]
# Final tip: make sure you have answered every question and filled in all the required code by running through the notebook and searching for *YOUR ANSWER HERE* and *YOUR CODE HERE*!
#
# Good luck!

# %% [markdown]
# ---

# %% [markdown]
# # Lab: Pandas
#
# This lab will focus on data cleanup, analysis and visualization.
#
# Three new libraries will be used: *matplotlib* and *seaborn*, both visualization libraries, and *pandas* a data manipulation library. While Pandas does share some functionality with SQL in regards to data manipulation, Pandas is often more easy to use in an interactive way, as is typically done in data exploration (assuming one is more fluent in Python than SQL).
#
# Pandas enables us to use DataFrames. A DataFrame is a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns).
# A dataframe can be created from a numpy ndarray, a list of dictionaries, and many other options.
# Dataframes support many types of data manipulation operations and can be used to plot the data in various ways.
# Throughout this lab you will have to get familiar with pandas. The [pandas API documentation](https://pandas.pydata.org/pandas-docs/stable/reference/index.html) wil be your first source of information to check when you want to know more about pandas. A second handy reference is the [Pandas Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf).
#
# If this is your first pandas experience, we advise to do the [10 minutes of pandas](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html).
#
# Note that all exercises in this lab are meant to be solved using Pandas. Avoid coding functionality that is already available in Pandas. (For example, you should not need any `for` loop in your code!)

# %% [markdown]
# ## Mimic-III
#
# This lab uses data from the Mimic dataset. However, to avoid SQL queries, we will work with local data (and limit ourselves to the smaller tables).
#
# You can refer to online sources for more details on the data format:
# - https://mimic.physionet.org/gettingstarted/overview/
# - https://mit-lcp.github.io/mimic-schema-spy/tables/patients.html

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Either load in the data using the database credentials from last lab.
import psycopg2

try:
    conn = psycopg2.connect(dbname='mimic',
                            user='student',
                            password='dahcc',
                            host="193.190.127.226",
                            port=5432,
                            options='-c statement_timeout=15s')

    admissions = pd.read_sql_query("SELECT * FROM mimiciii.admissions;", conn)
    patients = pd.read_sql_query("SELECT * FROM mimiciii.patients;", conn)
    items = pd.read_sql_query("SELECT * FROM mimiciii.d_items;", conn)
except psycopg2.OperationalError:
    print("Fill in the hostname!")

# Or load them by downloading the files from the MIMIC website.
# These CSV files are part of the MIMIC-III dataset: https://mimic.physionet.org/gettingstarted/dbsetup/

# admissions = pd.read_csv('data/ADMISSIONS.csv', parse_dates=['ADMITTIME', 'DISCHTIME', 'EDREGTIME', 'EDOUTTIME']).rename(columns=str.lower)
# patients = pd.read_csv('data/PATIENTS.csv', parse_dates=['DOB', 'DOD', 'DOD_HOSP', 'DOD_SSN']).rename(columns=str.lower)
# items = pd.read_csv('data/D_ITEMS.csv').rename(columns=str.lower)
# Out:
# Fill in the hostname!

# %%
# Note: if you use the downloaded files, do not include them in your submission to Ufora.

# %%
admissions.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 admissions.head(5)
#
# NameError: name 'admissions' is not defined

# %%
patients.head(5)
# Out:
#    row_id  subject_id gender        dob        dod   dod_hosp dod_ssn  \
# 0     234         249      F 2075-03-13        NaT        NaT     NaT
# 1     235         250      F 2164-12-27 2188-11-22 2188-11-22     NaT
# 2     236         251      M 2090-03-15        NaT        NaT     NaT
# 3     237         252      M 2078-03-06        NaT        NaT     NaT
# 4     238         253      F 2089-11-26        NaT        NaT     NaT
#
#    expire_flag
# 0            0
# 1            1
# 2            0
# 3            0
# 4            0

# %%
items.head(5)
# Out:
#    row_id  itemid                                        label abbreviation  \
# 0     457     497  Patient controlled analgesia (PCA) [Inject]         None
# 1     458     498                            PCA Lockout (Min)         None
# 2     459     499                               PCA Medication         None
# 3     460     500                               PCA Total Dose         None
# 4     461     501                           PCV Exh Vt (Obser)         None
#
#   dbsource      linksto category unitname param_type conceptid
# 0  carevue  chartevents     None     None       None      None
# 1  carevue  chartevents     None     None       None      None
# 2  carevue  chartevents     None     None       None      None
# 3  carevue  chartevents     None     None       None      None
# 4  carevue  chartevents     None     None       None      None

# %% [markdown]
# ## Data Cleanup
#
# Data quality can depend quite a bit depending on the source of the data. Luckily, the MIMIC dataset already has good quality as it is based on the database dumps.
#
# **Verify all ids in all tables are unique.**

# %%
number_unique_subject_ids = patients['subject_id'].nunique()
number_subject_records = patients['subject_id'].count()
number_unique_admission_ids = admissions['hadm_id'].nunique()
number_admission_records = admissions['hadm_id'].count()
number_unique_item_ids = items['itemid'].nunique()
number_item_records = items['label'].count()

print(f"unique subject ids: {number_unique_subject_ids}\nsubject records: {number_subject_records}\n")
print(f"unique admissions: {number_unique_admission_ids}\nadmission records: {number_admission_records}")
print(f"unique item ids: {number_unique_item_ids}\nitem records: {number_item_records}")

# Every id in the tables is unique!
# Out:
# unique subject ids: 46520
# subject records: 46520
#
# unique admissions: 58976
# admission records: 58976
# unique item ids: 12487
# item records: 12484

# %%
print("Subjects:", number_unique_subject_ids, number_subject_records)
print("Admissions:", number_unique_admission_ids, number_admission_records)
print("Items:", number_unique_item_ids, number_item_records)
# Out:
# Subjects: 46520 46520
# Admissions: 58976 58976
# Items: 12487 12484

# %% [markdown]
# The [D_ITEMS documentation](https://mimic.physionet.org/mimictables/d_items/) mentions that the entries originate from 2 different databases, so multiple itemids exist for the same label.
# **Find ALL labels that have multiple itemids. (Assume only perfect matches are duplicates, do not bother with abbreviations.)**

# %%
# E.g.: "Heart Rate" is a duplicate label
items[(items.itemid == 211) | (items.itemid == 220045)]
# Out:
#        row_id  itemid       label abbreviation    dbsource      linksto  \
# 475       212     211  Heart Rate         None     carevue  chartevents
# 11499   12712  220045  Heart Rate           HR  metavision  chartevents
#
#                   category unitname param_type conceptid
# 475                   None     None       None      None
# 11499  Routine Vital Signs      bpm    Numeric      None

# %%
duplicates = items['label'].duplicated()
duplicate_labels = []

dup_index = [i for i, x in enumerate(duplicates) if x]

# print(items['label'])

# for i in range(3000):
#     if 

for index in dup_index:
    print(items.iloc[[index]]['label'])


# YOUR CODE HERE
# raise NotImplementedError()
# Out:
# 2463    CVP Alarm [Low]
# Name: label, dtype: object
# 2464    HR Alarm [Low]
# Name: label, dtype: object
# 4394    protonics
# Name: label, dtype: object
# 4395    thoracentesis
# Name: label, dtype: object
# 4421    ALBUMIN
# Name: label, dtype: object
# 4422    protonix
# Name: label, dtype: object
# 4423    PANTOPRAZOLE
# Name: label, dtype: object
# 4425    cisatricurium
# Name: label, dtype: object
# 4451    Narcan
# Name: label, dtype: object
# 4456    Precedex
# Name: label, dtype: object
# 4459    Bivalirudin
# Name: label, dtype: object
# 4460    Lepirudin
# Name: label, dtype: object
# 4770    [Color]
# Name: label, dtype: object
# 4776    Hernia [Left]
# Name: label, dtype: object
# 4777    Hernia [Right]
# Name: label, dtype: object
# 4778    IV #1 [Location]
# Name: label, dtype: object
# 4779    IV #2 [Location]
# Name: label, dtype: object
# 4780    IV #3 [Location]
# Name: label, dtype: object
# 4781    IV #4 [Location]
# Name: label, dtype: object
# 4782    IV #5 [Location]
# Name: label, dtype: object
# 4798    CVP Alarm [High]
# Name: label, dtype: object
# 4799    HR Alarm [High]
# Name: label, dtype: object
# 4811    Stool [Color]
# Name: label, dtype: object
# 4817    GI Tube #1 [Site]
# Name: label, dtype: object
# 4818    GI Tube #2 [Site]
# Name: label, dtype: object
# 4879    Xigris
# Name: label, dtype: object
# 4894    D5W
# Name: label, dtype: object
# 4897    Calcium Gluconate
# Name: label, dtype: object
# 4898    KCL
# Name: label, dtype: object
# 4899    MVI
# Name: label, dtype: object
# 4901    Dopamine
# Name: label, dtype: object
# 4902    Isuprel
# Name: label, dtype: object
# 5057    PPN
# Name: label, dtype: object
# 5198    PROTONIX MG/HR
# Name: label, dtype: object
# 5201    octreotide
# Name: label, dtype: object
# 5214    QUINIDINE
# Name: label, dtype: object
# 5216    KPHOS
# Name: label, dtype: object
# 5237    Flolan
# Name: label, dtype: object
# 5253    flolan
# Name: label, dtype: object
# 5267    Potassium
# Name: label, dtype: object
# 5286    ns bolus
# Name: label, dtype: object
# 5288    KPhos
# Name: label, dtype: object
# 5296    Thoracentesis
# Name: label, dtype: object
# 5298    Demerol
# Name: label, dtype: object
# 5312    FLOLAN
# Name: label, dtype: object
# 5335    d5w 10gm ca+ glucon
# Name: label, dtype: object
# 5338    MgSO4
# Name: label, dtype: object
# 5345    Protonix
# Name: label, dtype: object
# 5346    METHYLPRED 450MG/HR
# Name: label, dtype: object
# 5369    Nicardipine mg/hr
# Name: label, dtype: object
# 5371    cyclosporine
# Name: label, dtype: object
# 5397    CARIPORIDE CC/HR
# Name: label, dtype: object
# 5405    Amiodarone mg/hr
# Name: label, dtype: object
# 5406    CARIPORIDE ML/HR
# Name: label, dtype: object
# 5416    Bupivacaine
# Name: label, dtype: object
# 5420    CARIPORIDE
# Name: label, dtype: object
# 5438    Precedex mcg/kg/hr
# Name: label, dtype: object
# 5442    Cisat mcg/kg/min
# Name: label, dtype: object
# 5511    NS Bolus
# Name: label, dtype: object
# 5516    ALCOHOL 10%DRIP G/HR
# Name: label, dtype: object
# 5522    alteplase
# Name: label, dtype: object
# 5527    nimbex
# Name: label, dtype: object
# 5535    Cisat mcg/kg/hr
# Name: label, dtype: object
# 5569    corlopam mcgs/kg/min
# Name: label, dtype: object
# 5574    KETAMINE MG/HR
# Name: label, dtype: object
# 5583    Alcohol Gm/hour
# Name: label, dtype: object
# 5590    ALCOHOL GTT ML/HR
# Name: label, dtype: object
# 5622    Epidural
# Name: label, dtype: object
# 5670    Sodium Chloride
# Name: label, dtype: object
# 5671    Potassium Chloride
# Name: label, dtype: object
# 5722    Nicardipine
# Name: label, dtype: object
# 5724    IVIG
# Name: label, dtype: object
# 5770    Platelets
# Name: label, dtype: object
# 5780    Calcium Chloride
# Name: label, dtype: object
# 5783    Magnesium Sulfate
# Name: label, dtype: object
# 5784    Potassium Phosphate
# Name: label, dtype: object
# 5786    TPN
# Name: label, dtype: object
# 5793    Insulin
# Name: label, dtype: object
# 5795    Lidocaine
# Name: label, dtype: object
# 5797    Vasopressin
# Name: label, dtype: object
# 5808    Folate
# Name: label, dtype: object
# 5809    Solumedrol
# Name: label, dtype: object
# 5835    Cisatracurium
# Name: label, dtype: object
# 5838    Fentanyl
# Name: label, dtype: object
# 5841    Lasix
# Name: label, dtype: object
# 5842    Midazolam
# Name: label, dtype: object
# 5843    Morphine Sulfate
# Name: label, dtype: object
# 5848    TPA
# Name: label, dtype: object
# 5851    Ativan
# Name: label, dtype: object
# 5856    Ketamine
# Name: label, dtype: object
# 5860    THAM
# Name: label, dtype: object
# 5900    Xygris
# Name: label, dtype: object
# 5909    Verapamil
# Name: label, dtype: object
# 5966    nicardipine gtt
# Name: label, dtype: object
# 5982    aprotinin cc/hr
# Name: label, dtype: object
# 5983    nimbex mcg/kg/min
# Name: label, dtype: object
# 5995    Precedex (mcg/kg/hr)
# Name: label, dtype: object
# 6032    APROTONIN
# Name: label, dtype: object
# 6036    solumedrol drip
# Name: label, dtype: object
# 6066    study drug
# Name: label, dtype: object
# 6068    Mucomyst
# Name: label, dtype: object
# 6082    demerol
# Name: label, dtype: object
# 6085    DRAIN FLUSH
# Name: label, dtype: object
# 6090    Pantoprazole
# Name: label, dtype: object
# 6097    epidural
# Name: label, dtype: object
# 6100    pad change
# Name: label, dtype: object
# 6103    ileostomy
# Name: label, dtype: object
# 6111    Protonix mg/hr
# Name: label, dtype: object
# 6145    NS bolus
# Name: label, dtype: object
# 6162    ngt residual
# Name: label, dtype: object
# 6196    Nipple Type
# Name: label, dtype: object
# 6214    JP DRAIN
# Name: label, dtype: object
# 6215    PROTONIX
# Name: label, dtype: object
# 6235    normal saline bolus
# Name: label, dtype: object
# 6246    Magnesium
# Name: label, dtype: object
# 6255    Acetylcysteine
# Name: label, dtype: object
# 6270    CT site
# Name: label, dtype: object
# 6272    mucous fistula
# Name: label, dtype: object
# 6288    enema
# Name: label, dtype: object
# 6311    Octreotide
# Name: label, dtype: object
# 6328    pigtail flush
# Name: label, dtype: object
# 6338    methadone
# Name: label, dtype: object
# 6356    ostomy
# Name: label, dtype: object
# 6361    Hernia
# Name: label, dtype: object
# 6461    SPIT
# Name: label, dtype: object
# 6494    SOLUMEDROL DRIP
# Name: label, dtype: object
# 6515    vasopressin unit/min
# Name: label, dtype: object
# 6525    Methylprednisolone
# Name: label, dtype: object
# 6546    LUMBAR DRAIN
# Name: label, dtype: object
# 6601    mushroom catheter
# Name: label, dtype: object
# 6638    methylprednisolone
# Name: label, dtype: object
# 6653    ETOH Grams/hour
# Name: label, dtype: object
# 6654    multivitamins
# Name: label, dtype: object
# 6657    Aprotinin cc/hr
# Name: label, dtype: object
# 6666    aprotinine
# Name: label, dtype: object
# 6681    sodium bicarb
# Name: label, dtype: object
# 6720    XYGRIS
# Name: label, dtype: object
# 6734    xigris mcg/kg/hr
# Name: label, dtype: object
# 6735    Nicardipine (mg/h)
# Name: label, dtype: object
# 6756    alcohol gtt
# Name: label, dtype: object
# 6757    Sodium Bicarb
# Name: label, dtype: object
# 6790    Ca++ Gluconate
# Name: label, dtype: object
# 6796    Nicardipine gtt
# Name: label, dtype: object
# 6850    LR
# Name: label, dtype: object
# 6889    Amphotericin
# Name: label, dtype: object
# 6930    Primo study cc/hr
# Name: label, dtype: object
# 7134    IVPPI
# Name: label, dtype: object
# 7163    Glucagon infusion
# Name: label, dtype: object
# 7215    bupivacaine
# Name: label, dtype: object
# 7379    Multivitamin
# Name: label, dtype: object
# 7382    pantoprazole
# Name: label, dtype: object
# 7390    xygris
# Name: label, dtype: object
# 7392    glucagon
# Name: label, dtype: object
# 7478    BLADDER PRESSURE
# Name: label, dtype: object
# 7510    Hep Flush
# Name: label, dtype: object
# 7518    Bicarb
# Name: label, dtype: object
# 7529    cyclosporin
# Name: label, dtype: object
# 7530    mucomyst
# Name: label, dtype: object
# 7550    D5W & 40Gm CaGluc
# Name: label, dtype: object
# 7565    circ
# Name: label, dtype: object
# 7707    Ketamine 100mg/50ml
# Name: label, dtype: object
# 7800    protonix 80mg/250cc
# Name: label, dtype: object
# 7867    dexmedetomidine
# Name: label, dtype: object
# 7892    Isoproterenol
# Name: label, dtype: object
# 7898    Acetylcysteine mg/hr
# Name: label, dtype: object
# 7903    TPA MG/HR
# Name: label, dtype: object
# 7904    Albumin
# Name: label, dtype: object
# 7932    Dextran
# Name: label, dtype: object
# 7975    K phos
# Name: label, dtype: object
# 8151    right arm
# Name: label, dtype: object
# 8229    rituximab
# Name: label, dtype: object
# 8386    ALCOHOL
# Name: label, dtype: object
# 8387    SOLUMEDROL MG/KG/HR
# Name: label, dtype: object
# 8391    ALCOHOL 5% DRIP G/HR
# Name: label, dtype: object
# 8395    aprotanin
# Name: label, dtype: object
# 8404    aprotanine
# Name: label, dtype: object
# 8406    EPIDURAL
# Name: label, dtype: object
# 8414    FENOLDOPAM
# Name: label, dtype: object
# 8422    APROTININE
# Name: label, dtype: object
# 8433    other
# Name: label, dtype: object
# 8538    Protonix gtt
# Name: label, dtype: object
# 8549    ATG
# Name: label, dtype: object
# 8558    Kphos
# Name: label, dtype: object
# 8572    K Phos
# Name: label, dtype: object
# 8578    Cyclosporin
# Name: label, dtype: object
# 8600    rectal tube
# Name: label, dtype: object
# 8613    C.O.
# Name: label, dtype: object
# 8635    Spits
# Name: label, dtype: object
# 8647    D10W bolus
# Name: label, dtype: object
# 8665    CA GLUCONATE
# Name: label, dtype: object
# 8669    SOLUMEDROL DRIP.
# Name: label, dtype: object
# 8673    Ensure
# Name: label, dtype: object
# 8674    Ensure Plus
# Name: label, dtype: object
# 8676    Potassium Chloride
# Name: label, dtype: object
# 8679    Platelets
# Name: label, dtype: object
# 8680    Cryoprecipitate
# Name: label, dtype: object
# 8681    Cell Saver
# Name: label, dtype: object
# 8687    Current Goal
# Name: label, dtype: object
# 8688    Eye Care
# Name: label, dtype: object
# 8689    Skin Care
# Name: label, dtype: object
# 8690    Back Care
# Name: label, dtype: object
# 8691    Cough/Deep Breath
# Name: label, dtype: object
# 8692    Incentive Spirometry
# Name: label, dtype: object
# 8693    Pin Care
# Name: label, dtype: object
# 8694    Ostomy Care
# Name: label, dtype: object
# 8695    Collar Care
# Name: label, dtype: object
# 8757    Epidural Location
# Name: label, dtype: object
# 8767    Trach Care
# Name: label, dtype: object
# 8828    Daily Wake Up
# Name: label, dtype: object
# 8835    Assistance Device
# Name: label, dtype: object
# 8863    Novasource
# Name: label, dtype: object
# 8871    CT scan
# Name: label, dtype: object
# 8875    EEG
# Name: label, dtype: object
# 8878    Adenosine
# Name: label, dtype: object
# 8879    Epinephrine
# Name: label, dtype: object
# 8881    Aminophylline
# Name: label, dtype: object
# 8882    Amiodarone
# Name: label, dtype: object
# 8885    Esmolol
# Name: label, dtype: object
# 8886    Calcium Gluconate
# Name: label, dtype: object
# 8887    Diltiazem
# Name: label, dtype: object
# 8888    Cisatracurium
# Name: label, dtype: object
# 8890    Dobutamine
# Name: label, dtype: object
# 8891    Dopamine
# Name: label, dtype: object
# 8894    Ketamine
# Name: label, dtype: object
# 8895    Factor VIII
# Name: label, dtype: object
# 8896    Fentanyl
# Name: label, dtype: object
# 8906    Lumbar Puncture
# Name: label, dtype: object
# 8909    EKG
# Name: label, dtype: object
# 8975    intrathecal catheter
# Name: label, dtype: object
# 9078    Calcium
# Name: label, dtype: object
# 9088    Sucrose
# Name: label, dtype: object
# 9100    j-tube flush
# Name: label, dtype: object
# 9104    Umbi hernia
# Name: label, dtype: object
# 9122    PROTONIX DRIP
# Name: label, dtype: object
# 9124    CARIPROSIDE
# Name: label, dtype: object
# 9126    STUDY DRUG
# Name: label, dtype: object
# 9139    cariporide
# Name: label, dtype: object
# 9152    APROTANIN
# Name: label, dtype: object
# 9273    Fresh Frozen Plasma
# Name: label, dtype: object
# 9287    Mannitol 20%
# Name: label, dtype: object
# 9303    Whole Blood
# Name: label, dtype: object
# 9305    Skin Integrity
# Name: label, dtype: object
# 9307    Skin Color
# Name: label, dtype: object
# 9313    Doppler BP
# Name: label, dtype: object
# 9315    Parameters Checked
# Name: label, dtype: object
# 9361    Chest X-Ray
# Name: label, dtype: object
# 9379    Thoracentesis
# Name: label, dtype: object
# 9431    Daily Wake Up
# Name: label, dtype: object
# 9504    Barrier precautions in place (Bronch)
# Name: label, dtype: object
# 9507    Barrier precautions in place (PACEN)
# Name: label, dtype: object
# 9508    Barrier precautions in place (THCEN)
# Name: label, dtype: object
# 9516    CAM-ICU Disorganized thinking
# Name: label, dtype: object
# 9517    CAM-ICU Inattention
# Name: label, dtype: object
# 9550    Hydralazine
# Name: label, dtype: object
# 9552    Lepirudin
# Name: label, dtype: object
# 9554    Milrinone
# Name: label, dtype: object
# 9555    Magnesium Sulfate
# Name: label, dtype: object
# 9557    Nesiritide
# Name: label, dtype: object
# 9558    Nicardipine
# Name: label, dtype: object
# 9559    Nitroprusside
# Name: label, dtype: object
# 9561    Vecuronium
# Name: label, dtype: object
# 9563    Procainamide
# Name: label, dtype: object
# 9564    Propofol
# Name: label, dtype: object
# 9565    Ranitidine
# Name: label, dtype: object
# 9566    Vasopressin
# Name: label, dtype: object
# 9567    Verapamil
# Name: label, dtype: object
# 9579    LUL Lung Sounds
# Name: label, dtype: object
# 9580    LLL Lung Sounds
# Name: label, dtype: object
# 9581    Respiratory Effort
# Name: label, dtype: object
# 9582    Cough Effort
# Name: label, dtype: object
# 9583    Cough Type
# Name: label, dtype: object
# 9585    CT #1 Suction Amount
# Name: label, dtype: object
# 9587    CT #1 Drainage
# Name: label, dtype: object
# 9588    CT #1 Dressing
# Name: label, dtype: object
# 9589    CT #1 Crepitus
# Name: label, dtype: object
# 9590    Oral Cavity
# Name: label, dtype: object
# 9592    Diet Type
# Name: label, dtype: object
# 9593    Abdominal Assessment
# Name: label, dtype: object
# 9594    Bowel Sounds
# Name: label, dtype: object
# 9595    Flatus
# Name: label, dtype: object
# 9599    GI #1 Tube Place Check
# Name: label, dtype: object
# 9601    Stool Management
# Name: label, dtype: object
# 9602    Stool Guaiac
# Name: label, dtype: object
# 9603    Urine Source
# Name: label, dtype: object
# 9605    GU Catheter Size
# Name: label, dtype: object
# 9606    Bladder Irrigation
# Name: label, dtype: object
# 9607    Support Systems
# Name: label, dtype: object
# 9650    Hemodialysis
# Name: label, dtype: object
# 9654    Paracentesis
# Name: label, dtype: object
# 9737    Bath
# Name: label, dtype: object
# 9743    Facial Droop
# Name: label, dtype: object
# 9745    Pronator Drift
# Name: label, dtype: object
# 9755    Seizure Activity
# Name: label, dtype: object
# 9756    Speech
# Name: label, dtype: object
# 9772    Family Communication
# Name: label, dtype: object
# 9773    Spiritual Support
# Name: label, dtype: object
# 9804    Restraint Type
# Name: label, dtype: object
# 9807    Position Change
# Name: label, dtype: object
# 9808    Range of Motion
# Name: label, dtype: object
# 9811    Sitter
# Name: label, dtype: object
# 9812    Education Learner
# Name: label, dtype: object
# 9814    Education Readiness
# Name: label, dtype: object
# 9815    Education Barrier
# Name: label, dtype: object
# 9816    Education Method
# Name: label, dtype: object
# 9817    Education Handout
# Name: label, dtype: object
# 9818    Education Response
# Name: label, dtype: object
# 9819    Head of Bed
# Name: label, dtype: object
# 9820    Turn
# Name: label, dtype: object
# 9821    Activity
# Name: label, dtype: object
# 9822    Assistance Device
# Name: label, dtype: object
# 9823    Activity Tolerance
# Name: label, dtype: object
# 9824    Therapeutic Bed
# Name: label, dtype: object
# 9830    Position
# Name: label, dtype: object
# 9834    Cervical Collar Type
# Name: label, dtype: object
# 9836    Traction/Immobile #1
# Name: label, dtype: object
# 9841    Dialysis Access Site
# Name: label, dtype: object
# 9845    System Integrity
# Name: label, dtype: object
# 9861    Cefazolin
# Name: label, dtype: object
# 9863    Ceftazidime
# Name: label, dtype: object
# 9867    Clindamycin
# Name: label, dtype: object
# 9871    Erythromycin
# Name: label, dtype: object
# 9873    Fluconazole
# Name: label, dtype: object
# 9876    Gentamicin
# Name: label, dtype: object
# 9882    Meropenem
# Name: label, dtype: object
# 9887    Oxacillin
# Name: label, dtype: object
# 9894    Rifampin
# Name: label, dtype: object
# 9897    Tobramycin
# Name: label, dtype: object
# 9914    Barrier precautions in place (LP)
# Name: label, dtype: object
# 9923    TF Residual
# Name: label, dtype: object
# 10017    Pacer Rate
# Name: label, dtype: object
# 10036    Respiratory Pattern
# Name: label, dtype: object
# 10037    RUL Lung Sounds
# Name: label, dtype: object
# 10038    RLL Lung Sounds
# Name: label, dtype: object
# 10042    Yawning
# Name: label, dtype: object
# 10052    Minute Volume
# Name: label, dtype: object
# 10058    Peak Insp. Pressure
# Name: label, dtype: object
# 10059    Plateau Pressure
# Name: label, dtype: object
# 10060    Mean Airway Pressure
# Name: label, dtype: object
# 10062    Total PEEP Level
# Name: label, dtype: object
# 10072    Digoxin
# Name: label, dtype: object
# 10088    Albumin
# Name: label, dtype: object
# 10089    Platelet Count
# Name: label, dtype: object
# 10090    Citrate
# Name: label, dtype: object
# 10159    Assisted Systole
# Name: label, dtype: object
# 10160    Augmented Diastole
# Name: label, dtype: object
# 10161    BAEDP
# Name: label, dtype: object
# 10166    IABP Mean
# Name: label, dtype: object
# 10183    QTc
# Name: label, dtype: object
# 10187    Epidural Medication
# Name: label, dtype: object
# 10188    Sputum Consistency
# Name: label, dtype: object
# 10197    Braden Moisture
# Name: label, dtype: object
# 10198    Braden Activity
# Name: label, dtype: object
# 10199    Braden Mobility
# Name: label, dtype: object
# 10200    Braden Nutrition
# Name: label, dtype: object
# 10217    Dextran 40
# Name: label, dtype: object
# 10219    Free Water
# Name: label, dtype: object
# 10220    Vancomycin
# Name: label, dtype: object
# 10221    Gastric Meds
# Name: label, dtype: object
# 10222    Lipids 20%
# Name: label, dtype: object
# 10233    Peritoneal Fluid
# Name: label, dtype: object
# 10241    D5NS
# Name: label, dtype: object
# 10243    LR
# Name: label, dtype: object
# 10245    Folic Acid
# Name: label, dtype: object
# 10246    Thiamine
# Name: label, dtype: object
# 10247    K Phos
# Name: label, dtype: object
# 10248    Na Phos
# Name: label, dtype: object
# 10249    Acyclovir
# Name: label, dtype: object
# 10250    Ambisome
# Name: label, dtype: object
# 10252    Ampicillin
# Name: label, dtype: object
# 10257    Mannitol
# Name: label, dtype: object
# 10260    Cyclosporine
# Name: label, dtype: object
# 10290    GI #1 Tube Place Method
# Name: label, dtype: object
# 10291    GI #2 Tube Place Method
# Name: label, dtype: object
# 10292    GI #3 Tube Place Method
# Name: label, dtype: object
# 10293    Neuro Drain Landmark
# Name: label, dtype: object
# 10300    Procan
# Name: label, dtype: object
# 10301    Procan Napa
# Name: label, dtype: object
# 10302    Phenobarbital
# Name: label, dtype: object
# 10304    FK506
# Name: label, dtype: object
# 10308    PTT
# Name: label, dtype: object
# 10309    INR
# Name: label, dtype: object
# 10310    Fibrinogen
# Name: label, dtype: object
# 10311    Thrombin
# Name: label, dtype: object
# 10312    Sed Rate
# Name: label, dtype: object
# 10402    ETT Position Change
# Name: label, dtype: object
# 10403    ART Lumen Volume
# Name: label, dtype: object
# 10404    VEN Lumen Volume
# Name: label, dtype: object
# 10410    Cuff Pressure
# Name: label, dtype: object
# 10416    CT #2 Crepitus
# Name: label, dtype: object
# 10417    CT #2 Drainage
# Name: label, dtype: object
# 10418    CT #2 Dressing
# Name: label, dtype: object
# 10420    CT #2 Suction Amount
# Name: label, dtype: object
# 10421    CT #3 Crepitus
# Name: label, dtype: object
# 10422    CT #4 Crepitus
# Name: label, dtype: object
# 10423    CT #3 Drainage
# Name: label, dtype: object
# 10424    CT #4 Drainage
# Name: label, dtype: object
# 10425    CT #3 Dressing
# Name: label, dtype: object
# 10426    CT #4 Dressing
# Name: label, dtype: object
# 10429    CT #3 Suction Amount
# Name: label, dtype: object
# 10430    CT #4 Suction Amount
# Name: label, dtype: object
# 10432    Chest Tube Site #3
# Name: label, dtype: object
# 10433    Chest Tube Site #4
# Name: label, dtype: object
# 10436    GI #2 Tube Place Check
# Name: label, dtype: object
# 10437    GI #3 Tube Place Check
# Name: label, dtype: object
# 10441    Traction/Immobile #2
# Name: label, dtype: object
# 10442    Traction/Immobile #3
# Name: label, dtype: object
# 10443    Traction/Immobile #4
# Name: label, dtype: object
# 10507    BUN
# Name: label, dtype: object
# 10516    D-Dimer
# Name: label, dtype: object
# 10517    Differential-Atyps
# Name: label, dtype: object
# 10518    Differential-Bands
# Name: label, dtype: object
# 10519    Differential-Basos
# Name: label, dtype: object
# 10520    Differential-Eos
# Name: label, dtype: object
# 10521    Differential-Lymphs
# Name: label, dtype: object
# 10522    Differential-Monos
# Name: label, dtype: object
# 10539    Ionized Calcium
# Name: label, dtype: object
# 10540    Lactic Acid
# Name: label, dtype: object
# 10543    Lipase
# Name: label, dtype: object
# 10544    Mixed Venous O2% Sat
# Name: label, dtype: object
# 10546    Phosphorous
# Name: label, dtype: object
# 10551    Serum Osmolality
# Name: label, dtype: object
# 10558    Triglyceride
# Name: label, dtype: object
# 10560    Uric Acid
# Name: label, dtype: object
# 10573    Traction/Immobile #1
# Name: label, dtype: object
# 10574    Traction/Immobile #2
# Name: label, dtype: object
# 10575    Traction/Immobile #3
# Name: label, dtype: object
# 10576    Traction/Immobile #4
# Name: label, dtype: object
# 10606    Heliox
# Name: label, dtype: object
# 10607    ETT Position Change
# Name: label, dtype: object
# 10610    None
# Name: label, dtype: object
# 10657    FLUID,OTHER
# Name: label, dtype: object
# 10659    PERITONEAL FLUID
# Name: label, dtype: object
# 10660    PLEURAL FLUID
# Name: label, dtype: object
# 10673    SWAB
# Name: label, dtype: object
# 10674    SWAB
# Name: label, dtype: object
# 10675    SWAB
# Name: label, dtype: object
# 10676    SWAB
# Name: label, dtype: object
# 10697    Corneal Reflex Right
# Name: label, dtype: object
# 10698    Corneal Reflex Left
# Name: label, dtype: object
# 10701    Inspiratory Time
# Name: label, dtype: object
# 10708    Nitric Oxide
# Name: label, dtype: object
# 10736    Sputum Source
# Name: label, dtype: object
# 10742    Heart Sounds
# Name: label, dtype: object
# 10828    Seizure Pads
# Name: label, dtype: object
# 10849    TISSUE
# Name: label, dtype: object
# 10852    URINE
# Name: label, dtype: object
# 10854    URINE
# Name: label, dtype: object
# 10857    SWAB
# Name: label, dtype: object
# 10861    Blood (EBV)
# Name: label, dtype: object
# 10946    Nasal Congestion
# Name: label, dtype: object
# 10948    Sweating
# Name: label, dtype: object
# 10966    Skin Condition
# Name: label, dtype: object
# 11003    Oral Care
# Name: label, dtype: object
# 11014    Barrier precautions in place (Intubation)
# Name: label, dtype: object
# 11029    Nutren 2.0 (3/4)
# Name: label, dtype: object
# 11059    Insertion kit used (A-Line)
# Name: label, dtype: object
# 11060    Hand cleansing prior to procedure (A-Line)
# Name: label, dtype: object
# 11061    Site cleaned with ChloraPrep(TM) (A-Line)
# Name: label, dtype: object
# 11062    Replaced previous Arterial line over wire
# Name: label, dtype: object
# 11063    Arterial line sutured
# Name: label, dtype: object
# 11064    Sterile field maintained throughout procedure ...
# Name: label, dtype: object
# 11066    Arterial Line ordered on POE
# Name: label, dtype: object
# 11069    Is alternative vascular access present (CVL)
# Name: label, dtype: object
# 11070    Insertion kit used (CVL)
# Name: label, dtype: object
# 11071    Hand cleansing prior to procedure (CVL)
# Name: label, dtype: object
# 11072    Site cleaned with ChloraPrep(TM) (CVL)
# Name: label, dtype: object
# 11073    Sterile field maintained throughout procedure ...
# Name: label, dtype: object
# 11074    Transparent dressing applied and dated (CVL)
# Name: label, dtype: object
# 11075    Central Line ordered on POE
# Name: label, dtype: object
# 11076    Follow-up chest X-RAY ordered (CVL)
# Name: label, dtype: object
# 11077    Immediate complications (CVL)
# Name: label, dtype: object
# 11080    Insertion kit used (PICC Line)
# Name: label, dtype: object
# 11138    PORPHYROMONAS SPECIES
# Name: label, dtype: object
# 11153    Slope
# Name: label, dtype: object
# 11193    Dilantin
# Name: label, dtype: object
# 11194    Fosphenytoin
# Name: label, dtype: object
# 11195    Keflex
# Name: label, dtype: object
# 11196    Isuprel
# Name: label, dtype: object
# 11203    Safety Measures
# Name: label, dtype: object
# 11279    FUSOBACTERIUM SPECIES
# Name: label, dtype: object
# 11320    Daily Weight
# Name: label, dtype: object
# 11321    Service
# Name: label, dtype: object
# 11333    ECMO
# Name: label, dtype: object
# 11334    Baseline Current/mA
# Name: label, dtype: object
# 11348    Behavior
# Name: label, dtype: object
# 11405    Restraint Device (Violent)
# Name: label, dtype: object
# 11406    Face to Face Eval (Violent)
# Name: label, dtype: object
# 11407    Restraint/Seclusion Observer Sheet
# Name: label, dtype: object
# 11469    Site cleaned with ChloraPrep(TM) (PICC)
# Name: label, dtype: object
# 11473    WBC
# Name: label, dtype: object
# 11478    Ammonia
# Name: label, dtype: object
# 11479    Amylase
# Name: label, dtype: object
# 11480    AST
# Name: label, dtype: object
# 11482    Cholesterol
# Name: label, dtype: object
# 11485    Creatinine
# Name: label, dtype: object
# 11488    LDH
# Name: label, dtype: object
# 11489    Magnesium
# Name: label, dtype: object
# 11491    ALT
# Name: label, dtype: object
# 11493    Total Protein
# Name: label, dtype: object
# 11499    Heart Rate
# Name: label, dtype: object
# 11502    Heart Rhythm
# Name: label, dtype: object
# 11526    Respiratory Rate
# Name: label, dtype: object
# 11530    Hemoglobin
# Name: label, dtype: object
# 11550    GI #1 Tube Place Method
# Name: label, dtype: object
# 11551    GI #2 Tube Place Method
# Name: label, dtype: object
# 11552    GI #3 Tube Place Method
# Name: label, dtype: object
# 11554    Arterial Base Excess
# Name: label, dtype: object
# 11660    Aminosyn 3.5%
# Name: label, dtype: object
# 11661    D5 Aminosyn 3.5%
# Name: label, dtype: object
# 11665    Folate
# Name: label, dtype: object
# 11667    Potassium Phosphate
# Name: label, dtype: object
# 11680    Sterile Water
# Name: label, dtype: object
# 11681    Lidocaine
# Name: label, dtype: object
# 11688    Dialysis Access Type
# Name: label, dtype: object
# 11693    Side Rails
# Name: label, dtype: object
# 11699    Restraint Location
# Name: label, dtype: object
# 11700    Circulation/Skin Integrity
# Name: label, dtype: object
# 11701    Position Change
# Name: label, dtype: object
# 11702    Range of Motion
# Name: label, dtype: object
# 11708    Restraints Evaluated
# Name: label, dtype: object
# 11745    2ND ISOLATE
# Name: label, dtype: object
# 11791    None
# Name: label, dtype: object
# 11793    PENICILLIN G
# Name: label, dtype: object
# 11795    CEFAZOLIN
# Name: label, dtype: object
# 11881    Barrier precautions in place (A-Line)
# Name: label, dtype: object
# 11895    Religion
# Name: label, dtype: object
# 11900    Foley
# Name: label, dtype: object
# 11901    Void
# Name: label, dtype: object
# 11910    Emesis
# Name: label, dtype: object
# 11914    Nasogastric
# Name: label, dtype: object
# 11971    Dressing applied and dated (THCEN)
# Name: label, dtype: object
# 11972    Follow-up X-RAY Ordered (THCEN)
# Name: label, dtype: object
# 11988    Readmission
# Name: label, dtype: object
# 11990    Insertion kit used (PA line)
# Name: label, dtype: object
# 11991    Hand cleansing prior to procedure (PA Line)
# Name: label, dtype: object
# 11993    Sterile field maintained throughout procedure ...
# Name: label, dtype: object
# 11994    Thermodilution (PA line)
# Name: label, dtype: object
# 11995    Fick (PA line)
# Name: label, dtype: object
# 11997    Transparent dressing applied and dated (PA line)
# Name: label, dtype: object
# 11998    PA line ordered on POE
# Name: label, dtype: object
# 11999    Follow-up X-RAYordered (PA Line)
# Name: label, dtype: object
# 12015    Dextrose 20%
# Name: label, dtype: object
# 12020    ETT Re-taped
# Name: label, dtype: object
# 12022    Ventilator Type
# Name: label, dtype: object
# 12023    Ventilator Mode
# Name: label, dtype: object
# 12032    Apnea Interval
# Name: label, dtype: object
# 12038    Orientation
# Name: label, dtype: object
# 12041    Speech
# Name: label, dtype: object
# 12042    Communication
# Name: label, dtype: object
# 12043    Gag Reflex
# Name: label, dtype: object
# 12044    Cough Reflex
# Name: label, dtype: object
# 12046    Follows Commands
# Name: label, dtype: object
# 12047    Spontaneous Movement
# Name: label, dtype: object
# 12049    RU Strength/Movement
# Name: label, dtype: object
# 12050    RL Strength/Movement
# Name: label, dtype: object
# 12051    LU Strength/Movement
# Name: label, dtype: object
# 12052    LL Strength/Movement
# Name: label, dtype: object
# 12053    Neuro Symptoms
# Name: label, dtype: object
# 12054    Seizure Activity
# Name: label, dtype: object
# 12056    Seizure Duration
# Name: label, dtype: object
# 12069    Graft/Flap Pulse
# Name: label, dtype: object
# 12072    Albumin 25%
# Name: label, dtype: object
# 12074    Albumin 5%
# Name: label, dtype: object
# 12078    Dextrose 10%
# Name: label, dtype: object
# 12118    Argatroban
# Name: label, dtype: object
# 12124    Morphine Sulfate
# Name: label, dtype: object
# 12125    Octreotide
# Name: label, dtype: object
# 12156    Ventricular Drain
# Name: label, dtype: object
# 12179    albumin
# Name: label, dtype: object
# 12211    MEROPENEM
# Name: label, dtype: object
# 12255    Pre-Admission Intake
# Name: label, dtype: object
# 12257    Cath Lab Intake
# Name: label, dtype: object
# 12268    PACU PO Intake
# Name: label, dtype: object
# 12269    Marital Status
# Name: label, dtype: object
# 12280    GT Flush
# Name: label, dtype: object
# 12287    Ectopy Type 2
# Name: label, dtype: object
# 12288    Ectopy Frequency 2
# Name: label, dtype: object
# 12292    OR EBL
# Name: label, dtype: object
# 12310    Sterile field maintained throughout procedure ...
# Name: label, dtype: object
# 12314    Immediate complications (PICC)
# Name: label, dtype: object
# 12317    Hand cleansing prior to procedure (Bronch)
# Name: label, dtype: object
# 12321    Endobronchial ultrasound (EBUS) (Bronch)
# Name: label, dtype: object
# 12322    Brushings (Bronch)
# Name: label, dtype: object
# 12323    Transbronchial biopsy (Bronch)
# Name: label, dtype: object
# 12324    Transbronchial needle aspirate (Bronch)
# Name: label, dtype: object
# 12325    Conscious sedation used (Bronch)
# Name: label, dtype: object
# 12326    Photodynamic therapy PDT (Bronch)
# Name: label, dtype: object
# 12327    Autofluorescence AF (Bronch)
# Name: label, dtype: object
# 12330    Hand Cleansing prior to procedure (Intubation)
# Name: label, dtype: object
# 12332    Stylette (Intubation)
# Name: label, dtype: object
# 12333    Bougie (Intubation)
# Name: label, dtype: object
# 12334    Tube Secured (Intubation)
# Name: label, dtype: object
# 12337    Hand cleansing prior to procedure (LP)
# Name: label, dtype: object
# 12341    Dressing applied and dated (LP)
# Name: label, dtype: object
# 12344    Insertion kit used (PACEN)
# Name: label, dtype: object
# 12345    Hand cleansing prior to procedure (PACEN)
# Name: label, dtype: object
# 12346    Site cleaned with ChloraPrep (PACEN)
# Name: label, dtype: object
# 12347    Dressing applied and dated (PACEN)
# Name: label, dtype: object
# 12350    Insertion kit used (THCEN)
# Name: label, dtype: object
# 12351    Hand cleansing prior to procedure (THCEN)
# Name: label, dtype: object
# 12352    Site cleansed with ChloraPrep (THCEN)
# Name: label, dtype: object
# 12361    Riker-SAS Scale
# Name: label, dtype: object
# 12362    Risk for Falls
# Name: label, dtype: object
# 12363    Code Status
# Name: label, dtype: object
# 12365    Health Care Proxy
# Name: label, dtype: object
# 12368    Bladder Pressure
# Name: label, dtype: object
# 12369    Orthostatic HR lying
# Name: label, dtype: object
# 12376    PCWP
# Name: label, dtype: object
# 12377    SvO2
# Name: label, dtype: object
# 12380    Daily Wake Up Deferred
# Name: label, dtype: object
# 12381    Pain Present
# Name: label, dtype: object
# 12382    Pain Type
# Name: label, dtype: object
# 12383    Pain Location
# Name: label, dtype: object
# 12384    Pain Cause
# Name: label, dtype: object
# 12385    Pain Level
# Name: label, dtype: object
# 12389    Untoward Effect
# Name: label, dtype: object
# 12390    Sensory Level
# Name: label, dtype: object
# 12391    Epidural Appearance
# Name: label, dtype: object
# 12392    NMB Medication
# Name: label, dtype: object
# 12393    Nerve Stimulated
# Name: label, dtype: object
# 12394    TOF Response/Twitch
# Name: label, dtype: object
# 12397    Paroxysmal Sweats
# Name: label, dtype: object
# 12398    Anxiety
# Name: label, dtype: object
# 12399    Auditory Disturbance
# Name: label, dtype: object
# 12401    Tactile Disturbances
# Name: label, dtype: object
# 12402    Visual Disturbances
# Name: label, dtype: object
# 12403    Headache
# Name: label, dtype: object
# 12405    Insomnia
# Name: label, dtype: object
# 12406    Seizure
# Name: label, dtype: object
# 12408    Ataxia
# Name: label, dtype: object
# 12409    Slurred Speech
# Name: label, dtype: object
# 12410    Drowsiness
# Name: label, dtype: object
# 12414    Airway Type
# Name: label, dtype: object
# 12421    Hand Cleansing Prior to Procedure (PICC)
# Name: label, dtype: object
# 12422    PICC Ordered on POE
# Name: label, dtype: object
# 12424    Transparent dressing applied and dated (PICC)
# Name: label, dtype: object
# 12425    Follow-up X-RAY Ordered (PICC)
# Name: label, dtype: object
# 12429    Unable to complete Airway Assessment (Intubation)
# Name: label, dtype: object
# 12446    Bed Bath
# Name: label, dtype: object

# %%
assert("Heart Rate" in duplicate_labels)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 assert("Heart Rate" in duplicate_labels)
#
# AssertionError:

# %% [markdown]
# **Knowing these duplicate features, describe how would you would work around this issue or adjust the data.**
# Describe which assumptions you are making in that approach (in regard to how the data would be used).

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# ## Feature Engineering
#
# Sometimes you'll want add new (derived) features to a dataset for easier visualisations or machine learning methods.
#
# The following APIs may get you started:
#
# - [Timestamp](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timestamp.html)
# - [Series.dt](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html)
# - [transform](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.transform.html)
# - [apply](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html)
#
# **Add a `admit_duration` column**
#
# Calculate the admission time (in days) and add it as a new column `admit_duration` to the admissions dataframe.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
assert("admit_duration" in admissions.columns)

# %% [markdown]
# **Add an `admit_age` column**
#
# Calculate the age of patients (in years) for each admission and add it as a new  column `admit_age` to the admissions dataframe. Keep in mind how the dates were changed according to the dataset documentation. (Correct for patients that would be 300 years old - set their age to 89.) Use the `merge` method to link patients to admissions, similar as you would perform a JOIN in SQL.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
assert('admit_age' in admissions.columns)

# %% [markdown]
# **Add a `status` column**
#
# Create a new column that indicates if a patient is alive, died inside the hospital, or died outside the hospital
# Use `ALIVE`, `HOSPITAL_DEATH`, `DEATH` as possible values.
# Add these entries to a new column called `status` in the patients dataframe.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
assert('status' in patients.columns)

# %% [markdown]
# ## Data Analysis
#
# Often, one starts with exploratory data analysis to get a feel of the structure and quality of the data. A need for additional cleanup may become apparant.
# In later stages, you will have a better view of what you wish to learn from the data.
#
# **How many admissions stated a `BUDDHIST` religion?**

# %%
num_buddhists = ...

# YOUR CODE HERE
raise NotImplementedError()

# %%
print(f"There are {num_buddhists} buddhists.")

# %% [markdown]
# **How many admissions stated a `MARRIED` marital status?**

# %%
num_married = ...

# YOUR CODE HERE
raise NotImplementedError()

# %%
print(f"There are {num_married} married people.")

# %% [markdown]
# **How many admissions stated a `MARRIED` `BUDDIST`?**

# %%
num_married_buddhists = ...

# YOUR CODE HERE
raise NotImplementedError()

# %%
print(f"There are {num_married_buddhists} married buddhists.")

# %% [markdown]
# **Create a dataframe showing the counts of every religion (rows) and every marital status (columns).**
#
# Use one of the following:
# - [pivot_table](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html)
# - [crosstab](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html)
# - [groupby](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html)

# %%
religion_marital_df = ...

# YOUR CODE HERE
raise NotImplementedError()

religion_marital_df

# %%
assert('DIVORCED' in religion_marital_df.columns)
assert('BAPTIST' in religion_marital_df.index)

# %% [markdown]
# **Use `describe` to find the summary statistics of `admit_duration` and `admit_age`.**

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## Visualisations
#
# Pandas provides [methods](https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#api-dataframe-plotting) to visualise dataframes/series, though controlling the exact layout may be less intuitive. Alternatively, [matplotlib](https://matplotlib.org/stable/tutorials/introductory/usage.html) provides a fine-grained API for creating visualisations. You will need more calls, but may find it easier to understand as each step is more explicit.

# %%
# E.g.: Pandas oneliner
patients.status.value_counts().plot.pie(autopct='%.2f', figsize=(4,4))

# %%
# E.g.: Matplotlib
plot_data = patients.status.value_counts()
fig = plt.figure(figsize=(4,4))
plt.pie(plot_data.values, labels=plot_data.index, autopct='%.2f')
plt.show()

# %% [markdown]
# **Create a piechart for both genders.**
#
# Plot 2 piecharts next to each other as above, showing the status of patients, one for each gender.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# **Histogram of admission time**
#
# Create a histogram that shows how many admissions take place at each hour of the day. The x-axis should show the time of day, ranging from 0 to 23 (buckets of one hour). The y-axis should show the number of admissions.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# **Create a scatter plot that show admission duration per age**
#
# Use the alpha parameter to better visualise the concentration of points. Use the figure size or axis limits to ensure enough detail is visible.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# **Create a stack bargraph**
#
# Visualise how the number of admission types (`admission_type`) evolves throughout different age groups. Define age groups to somewhat aggregate the data in a way that makes sense (e.g. groups spanning an age range of 5 years). Ensure your axes are labeled and use custom labels to indicate the age groups. In other words: you figure should be understandable without any additional explanation.

# %%
# YOUR CODE HERE
raise NotImplementedError()
